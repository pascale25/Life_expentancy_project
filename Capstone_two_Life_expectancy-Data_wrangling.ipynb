# %% [markdown]
# ## Factors Driving Life Expectancy : Do immunization matters?

# %% [markdown]
# ### import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os


from library.sb_utils import save_file

# %%
#kaggle datasets download -d kumarajarshi/life-expectancy-who
#import data
data = pd.read_csv('Life_Expectancy_Data.csv')

# %% [markdown]
# ## **Data wrangling**

# %%
data.head(5)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
data.shape
# Out:
# (2938, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
data_columns = data.columns
data_columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# #### 1. cleaning string - columns names
#
# Removing space in columns name and replace '-' wiht '_'

# %%
initial_col=data.columns
col1=[col.strip(' ') for col in initial_col]
new_col_name1=[col.replace(' ', '_') for col in col1]
new_col_name=[col.replace('-', '_') for col in new_col_name1]
new_col_name
# Out:
# ['Country',
#  'Year',
#  'Status',
#  'Life_expectancy',
#  'Adult_Mortality',
#  'infant_deaths',
#  'Alcohol',
#  'percentage_expenditure',
#  'Hepatitis_B',
#  'Measles',
#  'BMI',
#  'under_five_deaths',
#  'Polio',
#  'Total_expenditure',
#  'Diphtheria',
#  'HIV/AIDS',
#  'GDP',
#  'Population',
#  'thinness__1_19_years',
#  'thinness_5_9_years',
#  'Income_composition_of_resources',
#  'Schooling']

# %%
# replace new columns name in the dataframe
data.columns=new_col_name

# %%
data.head(3)
# Out:
#        Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
#
#    infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
#
#    Polio  Total_expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
#
#    thinness__1_19_years  thinness_5_9_years  Income_composition_of_resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
#
# [3 rows x 22 columns]

# %%
 # target Variable 
print(data[['Life_expectancy']].describe())
# Out:
#        Life_expectancy
# count      2928.000000
# mean         69.224932
# std           9.523867
# min          36.300000
# 25%          63.100000
# 50%          72.100000
# 75%          75.700000
# max          89.000000

# %% [markdown]
# #### 2. convert Year to datetime object

# %%
# convert Year to datetime object 
data.Year = pd.to_datetime(data.Year, format='%Y')

# %%
data['Year'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
# check the data type of all variables
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   datetime64[ns]
#  2   Status                           2938 non-null   object
#  3   Life_expectancy                  2928 non-null   float64
#  4   Adult_Mortality                  2928 non-null   float64
#  5   infant_deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage_expenditure           2938 non-null   float64
#  8   Hepatitis_B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under_five_deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total_expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15  HIV/AIDS                         2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18  thinness__1_19_years             2904 non-null   float64
#  19  thinness_5_9_years               2904 non-null   float64
#  20  Income_composition_of_resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: datetime64[ns](1), float64(16), int64(3), object(2)
# memory usage: 505.1+ KB

# %% [markdown]
# #### 3.Check missing value

# %%
#data.isna().sum() , data.isnull().sum()
MISSING= [data.isnull().sum(), 100 * data.isnull().mean()]
MISSING = pd.concat([data.isnull().sum(), 100 * data.isnull().mean()], axis=1)
MISSING.columns=['count','%'] 
MISSING.sort_values(by='%', ascending = False )
# Out:
#                                  count          %
# Population                         652  22.191967
# Hepatitis_B                        553  18.822328
# GDP                                448  15.248468
# Total_expenditure                  226   7.692308
# Alcohol                            194   6.603131
# Income_composition_of_resources    167   5.684139
# Schooling                          163   5.547992
# thinness_5_9_years                  34   1.157250
# thinness__1_19_years                34   1.157250
# BMI                                 34   1.157250
# Polio                               19   0.646698
# Diphtheria                          19   0.646698
# Life_expectancy                     10   0.340368
# Adult_Mortality                     10   0.340368
# HIV/AIDS                             0   0.000000
# Country                              0   0.000000
# Year                                 0   0.000000
# Measles                              0   0.000000
# percentage_expenditure               0   0.000000
# infant_deaths                        0   0.000000
# Status                               0   0.000000
# under_five_deaths                    0   0.000000

# %%
# according to the result above, population, Hepatitis, GDP has the highest percentage of missing value >15%

# %%
# 
data.isnull().sum().sort_values().plot(kind='bar', title='missing values per feature', xlabel='Features', ylabel='count')
plt.show()

# %% [markdown]
# #### 4 detecting unsual missing values

# %%
# data_null = data[['Country','Status','percentage_expenditure', 'Hepatitis_B', 'GDP', 'Population']].head(5)
data[(data['Country']== 'Yemen') & (data['Population'].isnull())].head(10)
# Out:
#      Country       Year      Status  Life_expectancy  Adult_Mortality  \
# 2890   Yemen 2015-01-01  Developing             65.7            224.0
# 2891   Yemen 2014-01-01  Developing             65.4            228.0
# 2892   Yemen 2013-01-01  Developing             65.4            226.0
# 2893   Yemen 2012-01-01  Developing             64.7            236.0
# 2894   Yemen 2011-01-01  Developing             64.6            234.0
# 2895   Yemen 2010-01-01  Developing             64.4            233.0
# 2896   Yemen 2009-01-01  Developing             64.1            235.0
# 2897   Yemen 2008-01-01  Developing             63.8            238.0
# 2898   Yemen 2007-01-01  Developing             63.4             24.0
# 2899   Yemen 2006-01-01  Developing             63.0            242.0
#
#       infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles  \
# 2890             37      NaN                     0.0         69.0      468
# 2891             37     0.01                     0.0         73.0      815
# 2892             36     0.04                     0.0         73.0      400
# 2893             36     0.04                     0.0         67.0     2177
# 2894             35     0.04                     0.0         69.0     2676
# 2895             35     0.06                     0.0         76.0      510
# 2896             36     0.03                     0.0         76.0      130
# 2897             37     0.04                     0.0         78.0        7
# 2898             38     0.05                     0.0         79.0       13
# 2899             39     0.04                     0.0         78.0     8079
#
#       ...  Polio  Total_expenditure  Diphtheria  HIV/AIDS  GDP  Population  \
# 2890  ...   63.0                NaN        69.0       0.1  NaN         NaN
# 2891  ...   67.0               5.64        73.0       0.1  NaN         NaN
# 2892  ...   67.0               5.78        73.0       0.1  NaN         NaN
# 2893  ...   68.0               5.73        67.0       0.1  NaN         NaN
# 2894  ...   69.0               5.40        69.0       0.1  NaN         NaN
# 2895  ...   77.0               5.17        76.0       0.1  NaN         NaN
# 2896  ...   76.0               5.32        76.0       0.1  NaN         NaN
# 2897  ...   78.0               5.12        78.0       0.1  NaN         NaN
# 2898  ...   79.0               4.92        79.0       0.1  NaN         NaN
# 2899  ...   78.0               4.82        78.0       0.1  NaN         NaN
#
#       thinness__1_19_years  thinness_5_9_years  \
# 2890                  13.6                13.4
# 2891                  13.7                13.5
# 2892                  13.7                13.5
# 2893                  13.7                13.6
# 2894                  13.7                13.6
# 2895                  13.7                13.7
# 2896                  13.8                13.7
# 2897                  13.8                13.7
# 2898                  13.8                13.8
# 2899                  13.9                13.8
#
#       Income_composition_of_resources  Schooling
# 2890                            0.499        9.0
# 2891                            0.500        9.0
# 2892                            0.498        9.0
# 2893                            0.494        9.0
# 2894                            0.493        8.6
# 2895                            0.488        8.5
# 2896                            0.483        8.4
# 2897                            0.480        8.5
# 2898                            0.477        8.6
# 2899                            0.475        8.7
#
# [10 rows x 22 columns]

# %%
# this result shows that percentage_expenditure has uncommun missing values which is zero

# %%
data.describe().T
# Out:
#                                   count          mean           std       min  \
# Life_expectancy                  2928.0  6.922493e+01  9.523867e+00  36.30000
# Adult_Mortality                  2928.0  1.647964e+02  1.242921e+02   1.00000
# infant_deaths                    2938.0  3.030395e+01  1.179265e+02   0.00000
# Alcohol                          2744.0  4.602861e+00  4.052413e+00   0.01000
# percentage_expenditure           2938.0  7.382513e+02  1.987915e+03   0.00000
# Hepatitis_B                      2385.0  8.094046e+01  2.507002e+01   1.00000
# Measles                          2938.0  2.419592e+03  1.146727e+04   0.00000
# BMI                              2904.0  3.832125e+01  2.004403e+01   1.00000
# under_five_deaths                2938.0  4.203574e+01  1.604455e+02   0.00000
# Polio                            2919.0  8.255019e+01  2.342805e+01   3.00000
# Total_expenditure                2712.0  5.938190e+00  2.498320e+00   0.37000
# Diphtheria                       2919.0  8.232408e+01  2.371691e+01   2.00000
# HIV/AIDS                         2938.0  1.742103e+00  5.077785e+00   0.10000
# GDP                              2490.0  7.483158e+03  1.427017e+04   1.68135
# Population                       2286.0  1.275338e+07  6.101210e+07  34.00000
# thinness__1_19_years             2904.0  4.839704e+00  4.420195e+00   0.10000
# thinness_5_9_years               2904.0  4.870317e+00  4.508882e+00   0.10000
# Income_composition_of_resources  2771.0  6.275511e-01  2.109036e-01   0.00000
# Schooling                        2775.0  1.199279e+01  3.358920e+00   0.00000
#
#                                            25%           50%           75%  \
# Life_expectancy                      63.100000  7.210000e+01  7.570000e+01
# Adult_Mortality                      74.000000  1.440000e+02  2.280000e+02
# infant_deaths                         0.000000  3.000000e+00  2.200000e+01
# Alcohol                               0.877500  3.755000e+00  7.702500e+00
# percentage_expenditure                4.685343  6.491291e+01  4.415341e+02
# Hepatitis_B                          77.000000  9.200000e+01  9.700000e+01
# Measles                               0.000000  1.700000e+01  3.602500e+02
# BMI                                  19.300000  4.350000e+01  5.620000e+01
# under_five_deaths                     0.000000  4.000000e+00  2.800000e+01
# Polio                                78.000000  9.300000e+01  9.700000e+01
# Total_expenditure                     4.260000  5.755000e+00  7.492500e+00
# Diphtheria                           78.000000  9.300000e+01  9.700000e+01
# HIV/AIDS                              0.100000  1.000000e-01  8.000000e-01
# GDP                                 463.935626  1.766948e+03  5.910806e+03
# Population                       195793.250000  1.386542e+06  7.420359e+06
# thinness__1_19_years                  1.600000  3.300000e+00  7.200000e+00
# thinness_5_9_years                    1.500000  3.300000e+00  7.200000e+00
# Income_composition_of_resources       0.493000  6.770000e-01  7.790000e-01
# Schooling                            10.100000  1.230000e+01  1.430000e+01
#
#                                           max
# Life_expectancy                  8.900000e+01
# Adult_Mortality                  7.230000e+02
# infant_deaths                    1.800000e+03
# Alcohol                          1.787000e+01
# percentage_expenditure           1.947991e+04
# Hepatitis_B                      9.900000e+01
# Measles                          2.121830e+05
# BMI                              8.730000e+01
# under_five_deaths                2.500000e+03
# Polio                            9.900000e+01
# Total_expenditure                1.760000e+01
# Diphtheria                       9.900000e+01
# HIV/AIDS                         5.060000e+01
# GDP                              1.191727e+05
# Population                       1.293859e+09
# thinness__1_19_years             2.770000e+01
# thinness_5_9_years               2.860000e+01
# Income_composition_of_resources  9.480000e-01
# Schooling                        2.070000e+01

# %% [markdown]
# #describe() help to identifty columns that may content missing value , min of these column is zero
# #here, we have infant_deaths, percentage_expenditure, Measles, under_five_deaths, Income_composition_of_resources and Schooling

# %%
columns=data.columns
columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life_expectancy', 'Adult_Mortality',
#        'infant_deaths', 'Alcohol', 'percentage_expenditure', 'Hepatitis_B',
#        'Measles', 'BMI', 'under_five_deaths', 'Polio', 'Total_expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness__1_19_years',
#        'thinness_5_9_years', 'Income_composition_of_resources', 'Schooling'],
#       dtype='object')

# %%
### print the list of all columns with zero as value

# %%
cols_zero=[]
for col in data.columns:
    for x in data[col].unique():
        if x == 0 :
            cols_zero.append(col)
print(cols_zero) # print all the columns with zero as value
# Out:
# ['infant_deaths', 'percentage_expenditure', 'Measles', 'under_five_deaths', 'Income_composition_of_resources', 'Schooling']
# C:\Users\HP\AppData\Local\Temp/ipykernel_32916/2072090697.py:4: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if x == 0 :

# %%
#ChEeck if zero is value in 'infant deaths'
data[data.infant_deaths == 0]['infant_deaths'][2::20].head(5)
# Out:
# 18     0
# 129    0
# 165    0
# 185    0
# 221    0
# Name: infant_deaths, dtype: int64

# %%
# count the number of zero in that columns
data[data.infant_deaths == 0]['infant_deaths'].count()
# Out:
# 848

# %%
#### count the number of zero in all columns

# %%
for col in cols_zero:
    nber_zero_col = data[data[col] == 0][col].count()
    print(col, ':', nber_zero_col)
# Out:
# infant_deaths : 848
# percentage_expenditure : 611
# Measles : 983
# under_five_deaths : 785
# Income_composition_of_resources : 130
# Schooling : 28

# %%
# Make a copy of dataset before transformation 
data_Zero_NAN = data.copy(deep=True)

# %%
#replacing uncommu missing data type with nan  ## np.nan, pd.NA, pd.NaT
# Set the 0 values of column  to np.nan
for col in cols_zero:
    nber_zero_col = data_Zero_NAN.loc[data_Zero_NAN[col] == 0, col] = np.nan

# %%
# verification that the 0 value was replace with np.nan 
data_Zero_NAN[data_Zero_NAN.infant_deaths == 0]['infant_deaths'][2::20].head(5)
# Out:
# Series([], Name: infant_deaths, dtype: float64)

# %%
# verification if any columns has 0 as value
(data_Zero_NAN == 0).any()
# Out:
# Country                            False
# Year                               False
# Status                             False
# Life_expectancy                    False
# Adult_Mortality                    False
# infant_deaths                      False
# Alcohol                            False
# percentage_expenditure             False
# Hepatitis_B                        False
# Measles                            False
# BMI                                False
# under_five_deaths                  False
# Polio                              False
# Total_expenditure                  False
# Diphtheria                         False
# HIV/AIDS                           False
# GDP                                False
# Population                         False
# thinness__1_19_years               False
# thinness_5_9_years                 False
# Income_composition_of_resources    False
# Schooling                          False
# dtype: bool

# %% [markdown]
# #now check again the percentage of missing value in the dataFrame

# %%
# percentage of missing data in each column
100 * data_Zero_NAN.isnull().mean().sort_values(ascending= False)
# Out:
# Measles                            33.458135
# infant_deaths                      28.863172
# under_five_deaths                  26.718856
# Population                         22.191967
# percentage_expenditure             20.796460
# Hepatitis_B                        18.822328
# GDP                                15.248468
# Income_composition_of_resources    10.108918
# Total_expenditure                   7.692308
# Alcohol                             6.603131
# Schooling                           6.501021
# BMI                                 1.157250
# thinness__1_19_years                1.157250
# thinness_5_9_years                  1.157250
# Polio                               0.646698
# Diphtheria                          0.646698
# Adult_Mortality                     0.340368
# Life_expectancy                     0.340368
# Year                                0.000000
# HIV/AIDS                            0.000000
# Status                              0.000000
# Country                             0.000000
# dtype: float64

# %%
MISS=100 * data_Zero_NAN.isnull().mean().sort_values()
MISS.plot(kind='bar', title='% of missing values', xlabel='Features', ylabel='%')
plt.show()

# %% [markdown]
# ### missing data visualisation and analysis

# %%
# visualise missing data 
import missingno as msno

# %%
# Note that we've used a proprietary display() function instead of plt.show() to make it easier for you to view the output.

# %%
msno.matrix(data_Zero_NAN)
display("/usr/local/share/datasets/matrix.png")
#plt.show()
# Out:
# '/usr/local/share/datasets/matrix.png'

# %%
msno.bar(data_Zero_NAN)
display("/usr/local/share/datasets/matrix.png")
# Out:
# '/usr/local/share/datasets/matrix.png'

# %%
# Plot missingness dendrogram 
msno.dendrogram(data_Zero_NAN)

# Show plot
plt.show()

# %%
# Visualize the correlation of missingness between variables
msno.heatmap(data_Zero_NAN)
display("/usr/local/share/datasets/matrix.png")
# Out:
# '/usr/local/share/datasets/matrix.png'

# %%
# the result above show a correlation of many features 
# mortality and life_expentancy
# under_five_death and infant_deaths
# total expenditure and alcohol
#

# %% [markdown]
# ### Outliers visualization and treatment

# %%
# https://medium.com/analytics-vidhya/outlier-treatment-9bbe87384d02
# https://towardsdatascience.com/detecting-and-treating-outliers-in-python-part-3-dcb54abaf7b0
# Applying Winzorization for Outliers
# https://www.kaggle.com/fulyakoncu/life-expectancy-who-eda-predictions
# https://www.analyticsvidhya.com/blog/2021/03/zooming-out-a-look-at-outlier-and-how-to-deal-with-them-indata-science/

# %% [markdown]
# #### visualization of Outliers

# %%
 sns.boxplot(y=data_Zero_NAN.Population, data=data_Zero_NAN)

# %%
#colNames = df.columns.tolist()
for col in columns[3:]:
    if data_Zero_NAN[col].dtype == "object": 
        continue
    plt.figure(figsize=(10,3))
    plt.subplot(1,2,1) # one row , two columns for each columns
    #plt.boxplot(data_Zero_NAN[col]) # not working, find later why
    sns.boxplot(y=col, data=data_Zero_NAN) # refert to part one 
    plt.title(col)
    plt.ylabel(col)
    plt.xlabel(col)
    
    plt.subplot(1,2,2)
    #sns.distplot(data_Zero_NAN[col], kde=False)
    plt.hist(data_Zero_NAN[col])  # refer to par two
    plt.title(col)
    plt.ylabel(col)
    plt.xlabel('Bins')
    plt.show()

# %%
#  nunique () return Series with number of distinct observations over requested axis. 
data_Zero_NAN.nunique(axis=0).sort_values(ascending=False)
# Out:
# GDP                                2490
# percentage_expenditure             2327
# Population                         2278
# Alcohol                            1076
# Measles                             957
# Total_expenditure                   818
# Income_composition_of_resources     624
# BMI                                 608
# Adult_Mortality                     425
# Life_expectancy                     362
# under_five_deaths                   251
# infant_deaths                       208
# thinness_5_9_years                  207
# HIV/AIDS                            200
# thinness__1_19_years                200
# Country                             193
# Schooling                           172
# Hepatitis_B                          87
# Diphtheria                           81
# Polio                                73
# Year                                 16
# Status                                2
# dtype: int64

# %% [markdown]
# ###### TReatment of Outlier first (and next, will be the treatement of missing data

# %% [markdown]
# #### Managing outlier using winsorization
# In the Winsorize Method, we limit outliers with an upper and lower limit. We will set the limits. We will make our upper and lower limits for data our new maximum and minimum points.
#
# Winsorization is a symmetric process that replaces the k smallest and the k largest data values.

# %%
## https://hersanyagci.medium.com/detecting-and-handling-outliers-with-pandas-7adbfcd5cad8
## https://towardsdatascience.com/detecting-and-treating-outliers-in-python-part-3-dcb54abaf7b0

# %%
from scipy.stats.mstats import winsorize

# %%
# Make a copy dataset 
data_outlier_vinso = data_Zero_NAN.copy(deep=True)

# %%
data_outlier_vinso['Population'].quantile(0.01)
# Out:
# 444.0

# %%
data_outlier_vinso['Population'].quantile(0.92)
# Out:
# 32864644.000000007

# %%
Vinso_population = winsorize(data_outlier_vinso.Population, (0.01, 0.02))
Vinso_population
# Out:
# masked_array(data=[33736494.,   327582., 31731688., ...,   125525.,
#                    12366165., 12222251.],
#              mask=False,
#        fill_value=1e+20)

# %%
sns.boxplot(Vinso_population)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
for col in data_outlier_vinso.columns[3:]:
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    sns.boxplot(x=col,data=data_outlier_vinso)
    plt.title(col)

    plt.subplot(1,2,2)
    winsorized_data = winsorize(data_outlier_vinso[col],(0.01,0.01), inplace=True)
    sns.boxplot(winsorized_data)
    plt.title("winsorized "+col )
    plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# vinsorize data 
data_outlier_vinso.describe().T
# Out:
#                                   count          mean           std  \
# Life_expectancy                  2938.0  6.930211e+01  9.516758e+00
# Adult_Mortality                  2938.0  1.659922e+02  1.254285e+02
# infant_deaths                    2090.0  4.259952e+01  1.379414e+02
# Alcohol                          2744.0  4.602861e+00  4.052413e+00
# percentage_expenditure           2327.0  9.320992e+02  2.192968e+03
# Hepatitis_B                      2385.0  8.095639e+01  2.502136e+01
# Measles                          1955.0  3.636195e+03  1.390055e+04
# BMI                              2904.0  3.832379e+01  2.003941e+01
# under_five_deaths                2153.0  5.736229e+01  1.850772e+02
# Polio                            2938.0  8.267393e+01  2.333153e+01
# Total_expenditure                2712.0  5.939878e+00  2.495006e+00
# Diphtheria                       2938.0  8.244894e+01  2.362203e+01
# HIV/AIDS                         2938.0  1.654663e+00  4.437499e+00
# GDP                              2490.0  7.483273e+03  1.427011e+04
# Population                       2286.0  1.275338e+07  6.101210e+07
# thinness__1_19_years             2904.0  4.840668e+00  4.419171e+00
# thinness_5_9_years               2904.0  4.870317e+00  4.508882e+00
# Income_composition_of_resources  2641.0  6.586823e-01  1.616967e-01
# Schooling                        2747.0  1.212282e+01  3.128430e+00
#
#                                         min            25%           50%  \
# Life_expectancy                   45.600000      63.200000  7.210000e+01
# Adult_Mortality                    4.000000      74.000000  1.440000e+02
# infant_deaths                      1.000000       2.000000  9.000000e+00
# Alcohol                            0.010000       0.877500  3.755000e+00
# percentage_expenditure             1.142004      36.246202  1.551952e+02
# Hepatitis_B                        6.000000      77.000000  9.200000e+01
# Measles                            1.000000      17.000000  1.280000e+02
# BMI                                2.300000      19.300000  4.350000e+01
# under_five_deaths                  1.000000       3.000000  1.100000e+01
# Polio                              6.000000      78.000000  9.300000e+01
# Total_expenditure                  1.250000       4.260000  5.755000e+00
# Diphtheria                         6.000000      78.000000  9.300000e+01
# HIV/AIDS                           0.100000       0.100000  1.000000e-01
# GDP                               24.242323     463.935626  1.766948e+03
# Population                       795.000000  195793.250000  1.386542e+06
# thinness__1_19_years               0.200000       1.600000  3.300000e+00
# thinness_5_9_years                 0.100000       1.500000  3.300000e+00
# Income_composition_of_resources    0.306000       0.523000  6.870000e-01
# Schooling                          4.400000      10.200000  1.240000e+01
#
#                                           75%           max
# Life_expectancy                  7.570000e+01  8.800000e+01
# Adult_Mortality                  2.280000e+02  6.140000e+02
# infant_deaths                    3.300000e+01  1.800000e+03
# Alcohol                          7.702500e+00  1.787000e+01
# percentage_expenditure           6.302212e+02  1.947991e+04
# Hepatitis_B                      9.700000e+01  9.900000e+01
# Measles                          1.210000e+03  2.121830e+05
# BMI                              5.620000e+01  8.730000e+01
# under_five_deaths                4.600000e+01  2.500000e+03
# Polio                            9.700000e+01  9.900000e+01
# Total_expenditure                7.492500e+00  1.760000e+01
# Diphtheria                       9.700000e+01  9.900000e+01
# HIV/AIDS                         8.000000e-01  2.950000e+01
# GDP                              5.910806e+03  1.191727e+05
# Population                       7.420359e+06  1.293859e+09
# thinness__1_19_years             7.200000e+00  2.770000e+01
# thinness_5_9_years               7.200000e+00  2.860000e+01
# Income_composition_of_resources  7.840000e-01  9.480000e-01
# Schooling                        1.430000e+01  2.070000e+01

# %%
# non_vinzorize data  observe the difference in Min and Max columns
data_Zero_NAN.describe().T
# Out:
#                                   count          mean           std  \
# Life_expectancy                  2928.0  6.922493e+01  9.523867e+00
# Adult_Mortality                  2928.0  1.647964e+02  1.242921e+02
# infant_deaths                    2090.0  4.259952e+01  1.379414e+02
# Alcohol                          2744.0  4.602861e+00  4.052413e+00
# percentage_expenditure           2327.0  9.320938e+02  2.192970e+03
# Hepatitis_B                      2385.0  8.094046e+01  2.507002e+01
# Measles                          1955.0  3.636195e+03  1.390055e+04
# BMI                              2904.0  3.832125e+01  2.004403e+01
# under_five_deaths                2153.0  5.736229e+01  1.850772e+02
# Polio                            2919.0  8.255019e+01  2.342805e+01
# Total_expenditure                2712.0  5.938190e+00  2.498320e+00
# Diphtheria                       2919.0  8.232408e+01  2.371691e+01
# HIV/AIDS                         2938.0  1.742103e+00  5.077785e+00
# GDP                              2490.0  7.483158e+03  1.427017e+04
# Population                       2286.0  1.275338e+07  6.101210e+07
# thinness__1_19_years             2904.0  4.839704e+00  4.420195e+00
# thinness_5_9_years               2904.0  4.870317e+00  4.508882e+00
# Income_composition_of_resources  2641.0  6.584415e-01  1.622448e-01
# Schooling                        2747.0  1.211503e+01  3.148949e+00
#
#                                        min            25%           50%  \
# Life_expectancy                  36.300000      63.100000  7.210000e+01
# Adult_Mortality                   1.000000      74.000000  1.440000e+02
# infant_deaths                     1.000000       2.000000  9.000000e+00
# Alcohol                           0.010000       0.877500  3.755000e+00
# percentage_expenditure            0.099872      36.246202  1.551952e+02
# Hepatitis_B                       1.000000      77.000000  9.200000e+01
# Measles                           1.000000      17.000000  1.280000e+02
# BMI                               1.000000      19.300000  4.350000e+01
# under_five_deaths                 1.000000       3.000000  1.100000e+01
# Polio                             3.000000      78.000000  9.300000e+01
# Total_expenditure                 0.370000       4.260000  5.755000e+00
# Diphtheria                        2.000000      78.000000  9.300000e+01
# HIV/AIDS                          0.100000       0.100000  1.000000e-01
# GDP                               1.681350     463.935626  1.766948e+03
# Population                       34.000000  195793.250000  1.386542e+06
# thinness__1_19_years              0.100000       1.600000  3.300000e+00
# thinness_5_9_years                0.100000       1.500000  3.300000e+00
# Income_composition_of_resources   0.253000       0.523000  6.870000e-01
# Schooling                         2.800000      10.200000  1.240000e+01
#
#                                           75%           max
# Life_expectancy                  7.570000e+01  8.900000e+01
# Adult_Mortality                  2.280000e+02  7.230000e+02
# infant_deaths                    3.300000e+01  1.800000e+03
# Alcohol                          7.702500e+00  1.787000e+01
# percentage_expenditure           6.302212e+02  1.947991e+04
# Hepatitis_B                      9.700000e+01  9.900000e+01
# Measles                          1.210000e+03  2.121830e+05
# BMI                              5.620000e+01  8.730000e+01
# under_five_deaths                4.600000e+01  2.500000e+03
# Polio                            9.700000e+01  9.900000e+01
# Total_expenditure                7.492500e+00  1.760000e+01
# Diphtheria                       9.700000e+01  9.900000e+01
# HIV/AIDS                         8.000000e-01  5.060000e+01
# GDP                              5.910806e+03  1.191727e+05
# Population                       7.420359e+06  1.293859e+09
# thinness__1_19_years             7.200000e+00  2.770000e+01
# thinness_5_9_years               7.200000e+00  2.860000e+01
# Income_composition_of_resources  7.840000e-01  9.480000e-01
# Schooling                        1.430000e+01  2.070000e+01

# %% [markdown]
# describe show how vinzorization act on data
# exemple: check at the minimun value of life expentancy in both table (45 over 36)

# %% [markdown]
# ### label Encoder categerical variable

# %%
data_cat_encode = data_Zero_NAN.copy(deep=True)
data_cat_encode.head(3)
# Out:
#        Country       Year      Status  Life_expectancy  Adult_Mortality  \
# 0  Afghanistan 2015-01-01  Developing             65.0            263.0
# 1  Afghanistan 2014-01-01  Developing             59.9            271.0
# 2  Afghanistan 2013-01-01  Developing             59.9            268.0
#
#    infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles  ...  \
# 0           62.0     0.01               71.279624         65.0   1154.0  ...
# 1           64.0     0.01               73.523582         62.0    492.0  ...
# 2           66.0     0.01               73.219243         64.0    430.0  ...
#
#    Polio  Total_expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
#
#    thinness__1_19_years  thinness_5_9_years  Income_composition_of_resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
#
# [3 rows x 22 columns]

# %%
data_cat_encode = data_cat_encode.drop(columns='Country')

# %%
data_cat_encode = pd.get_dummies(data_cat_encode, drop_first=True)

# %%
#data_cat_encode['Country']=data_Zero_NAN['Country']

# %%
data_cat_encode.insert(0,'Country', data_Zero_NAN['Country'], allow_duplicates=True)

# %%
data_cat_encode.sample(5)
# Out:
#             Country       Year  Life_expectancy  Adult_Mortality  \
# 443   Côte d'Ivoire 2004-01-01             48.2            472.0
# 100         Armenia 2011-01-01             73.9            128.0
# 1537      Lithuania 2000-01-01             71.6              2.0
# 2414    South Sudan 2010-01-01             55.0            359.0
# 1025          Ghana 2000-01-01             57.2             38.0
#
#       infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles  \
# 443            64.0     3.08                     NaN         67.0   3466.0
# 100             1.0     4.09              260.996383         95.0      NaN
# 1537            NaN     9.87              373.260553         98.0     19.0
# 2414           27.0      NaN                     NaN          NaN      NaN
# 1025           43.0     1.60               20.654329          NaN  23068.0
#
#        BMI  ...  Total_expenditure  Diphtheria  HIV/AIDS          GDP  \
# 443   21.5  ...               5.24        67.0       6.5          NaN
# 100   51.9  ...               3.71        95.0       0.1  3526.978143
# 1537  56.9  ...               6.46        94.0       0.1  3297.354710
# 2414   NaN  ...                NaN         NaN       4.0  1562.239346
# 1025  19.5  ...               3.00        88.0       3.6   263.112468
#
#       Population  thinness__1_19_years  thinness_5_9_years  \
# 443          NaN                   7.3                 7.3
# 100    2875581.0                   2.0                 2.1
# 1537   3499536.0                   3.4                 3.4
# 2414    167192.0                   NaN                 NaN
# 1025  18938762.0                   9.2                 9.2
#
#       Income_composition_of_resources  Schooling  Status_Developing
# 443                               NaN        NaN                  1
# 100                             0.729       12.7                  1
# 1537                            0.745       14.0                  0
# 2414                              NaN        NaN                  1
# 1025                            0.480        7.7                  1
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Treatmenet of missing values

# %% [markdown]
# ##### Mean, mode, constant & median imputation
# ##### imputing as time_serie data  with fillna -- (ffill and bfill)
# ##### Impute with interpolate method
# ##### Imputing using fancyimpute (KNN imputation, MICE imputation)

# %%
 # https://medium.com/analytics-vidhya/outlier-treatment-9bbe87384d02
# https://towardsdatascience.com/detecting-and-treating-outliers-in-python-part-3-dcb54abaf7b0
# Applying Winzorization for Outliers
# https://www.kaggle.com/fulyakoncu/life-expectancy-who-eda-predictions
# https://www.analyticsvidhya.com/blog/2021/03/zooming-out-a-look-at-outlier-and-how-to-deal-with-them-indata-science

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# ###  Mean, mode, constant & median imputation

# %%
data_NAN_Imput = data_cat_encode.copy(deep=True)
# select only the numeric feature from the dataset
df_num = data_NAN_Imput.iloc[: , 2:]
df_num.sample(4)
# Out:
#       Life_expectancy  Adult_Mortality  infant_deaths  Alcohol  \
# 1534             71.6             22.0            NaN    11.29
# 176              76.9             69.0            NaN      NaN
# 1569             57.9            283.0           44.0     1.16
# 929              77.5             15.0            NaN     8.59
#
#       percentage_expenditure  Hepatitis_B  Measles   BMI  under_five_deaths  \
# 1534               80.997101         95.0      1.0  57.8                NaN
# 176                      NaN         98.0      NaN  63.6                NaN
# 1569               35.661251          NaN  35256.0  13.9               68.0
# 929               397.753369          NaN      NaN  55.5                NaN
#
#       Polio  Total_expenditure  Diphtheria  HIV/AIDS           GDP  \
# 1534   91.0               6.46        94.0       0.1    555.535669
# 176    98.0                NaN        98.0       0.1  22688.878240
# 1569   58.0               5.80        57.0       0.6    245.939659
# 929    96.0               7.22        99.0       0.1  24253.254200
#
#       Population  thinness__1_19_years  thinness_5_9_years  \
# 1534   3415213.0                   3.2                 3.2
# 176          NaN                   6.2                 6.1
# 1569   1576686.0                   8.7                 8.6
# 929     517629.0                   0.9                 0.9
#
#       Income_composition_of_resources  Schooling  Status_Developing
# 1534                            0.780       15.8                  0
# 176                             0.823       14.5                  1
# 1569                              NaN        8.0                  1
# 929                             0.847       17.3                  1

# %%
# Plot missingness dendrogram 
msno.dendrogram(data_NAN_Imput)

# Show plot
plt.show()

# %%
# Make a copy of dataframe
data_NAN_mean = df_num.copy(deep=True)

# Create mean imputer object
mean_imputer = SimpleImputer(strategy='mean')

# Impute mean values in the DataFrame 
data_NAN_mean.iloc[:,:] = mean_imputer.fit_transform(data_NAN_mean)

# %%
# Make a copy of the dataFrame
data_NAN_median = df_num.copy(deep=True)

# Create median imputer object
median_imputer = SimpleImputer(strategy='median')

# Impute median values in the DataFrame 
data_NAN_median.iloc[:, :] = median_imputer.fit_transform(data_NAN_median)

# %%
# Make a copy of diabetes
data_NAN_mode = df_num.copy(deep=True)

# Create mode imputer object
mode_imputer = SimpleImputer(strategy='most_frequent')

# Impute using most frequent value in the DataFrame 
data_NAN_mode.iloc[:, :] = mode_imputer.fit_transform(data_NAN_mode)

# %%
# Make a copy of df
data_NAN_constant = df_num.copy(deep=True)

# Create median imputer object
constant_imputer = SimpleImputer(strategy='constant', fill_value=0)

# Impute missing values to 0 in df_constant
data_NAN_constant.iloc[:, :] = constant_imputer.fit_transform(data_NAN_constant)

# %% [markdown]
# ####  Visualize imputations

# %%
# example of visualisation on population feature

# %%
# Set nrows and ncols to 2
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))
nullity = df_num.infant_deaths.isnull()+df_num.Measles.isnull()

# Create a dictionary of imputations
imputations = {'Mean Imputation': data_NAN_mean, 'Median Imputation': data_NAN_median, 
               'Most Frequent Imputation': data_NAN_mode, 'Constant Imputation': data_NAN_constant}

# Loop over flattened axes and imputations
for ax, df_key in zip(axes.flatten(), imputations):
    # Select and also set the title for a DataFrame
    imputations[df_key].plot(x='infant_deaths', y='Measles', kind='scatter', 
                          alpha=0.5, c=nullity, cmap='rainbow', ax=ax, 
                          colorbar=False, title=df_key)
plt.show()

# %% [markdown]
# ### Imputing using fancyimpute

# %%
from fancyimpute import KNN

# %%
# Import KNN from fancyimpute  # KNN finds most similar points for imputing
#from fancyimpute import KNN

# Copy of df to df_knn_imputed
df_knn_imputed = df_num.copy(deep=True)

# Initialize KNN
knn_imputer = KNN()

# Impute using fit_tranform on diabetes_knn_imputed
df_knn_imputed.iloc[:, :] = knn_imputer.fit_transform(df_knn_imputed)
# Out:
# Imputing row 1/2938 with 0 missing, elapsed time: 2.415
# Imputing row 101/2938 with 1 missing, elapsed time: 2.420
# Imputing row 201/2938 with 0 missing, elapsed time: 2.429
# Imputing row 301/2938 with 2 missing, elapsed time: 2.434
# Imputing row 401/2938 with 3 missing, elapsed time: 2.442
# Imputing row 501/2938 with 0 missing, elapsed time: 2.448
# Imputing row 601/2938 with 1 missing, elapsed time: 2.452
# Imputing row 701/2938 with 7 missing, elapsed time: 2.463
# Imputing row 801/2938 with 0 missing, elapsed time: 2.475
# Imputing row 901/2938 with 3 missing, elapsed time: 2.483
# Imputing row 1001/2938 with 0 missing, elapsed time: 2.490
# Imputing row 1101/2938 with 3 missing, elapsed time: 2.497
# Imputing row 1201/2938 with 1 missing, elapsed time: 2.504
# Imputing row 1301/2938 with 1 missing, elapsed time: 2.509
# Imputing row 1401/2938 with 2 missing, elapsed time: 2.515
# Imputing row 1501/2938 with 1 missing, elapsed time: 2.522
# Imputing row 1601/2938 with 0 missing, elapsed time: 2.528
# Imputing row 1701/2938 with 5 missing, elapsed time: 2.535
# Imputing row 1801/2938 with 0 missing, elapsed time: 2.543
# Imputing row 1901/2938 with 0 missing, elapsed time: 2.547
# Imputing row 2001/2938 with 1 missing, elapsed time: 2.553
# Imputing row 2101/2938 with 5 missing, elapsed time: 2.560
# Imputing row 2201/2938 with 6 missing, elapsed time: 2.572
# Imputing row 2301/2938 with 0 missing, elapsed time: 2.580
# Imputing row 2401/2938 with 0 missing, elapsed time: 2.594
# Imputing row 2501/2938 with 1 missing, elapsed time: 2.604
# Imputing row 2601/2938 with 7 missing, elapsed time: 2.612
# Imputing row 2701/2938 with 1 missing, elapsed time: 2.618
# Imputing row 2801/2938 with 5 missing, elapsed time: 2.630
# Imputing row 2901/2938 with 3 missing, elapsed time: 2.645

# %%
from fancyimpute import IterativeImputer

# %%
# Import IterativeImputer from fancyimpute ## MICE performe multiple regression for imputing 
#/ it is a very robost model for imputation

# Copy df_mice_imputed
df_mice_imputed = df_num.copy(deep=True)

# Initialize IterativeImputer
mice_imputer = IterativeImputer()

# Impute using fit_tranform on diabetes
df_mice_imputed.iloc[:, :] = mice_imputer.fit_transform(df_mice_imputed) # or (diabetes in fitting)

# %% [markdown]
# ## Evaluation of different imputation techniques

# %%
import statsmodels.api as sm

# %%
### define de baseline dataset where we drop all null value # df_base.dropna(how='any')

# %%
df_base = df_num.copy(deep=True)
df_base = df_base.dropna()
df_base.head(3)
# Out:
#    Life_expectancy  Adult_Mortality  infant_deaths  Alcohol  \
# 0             65.0            263.0           62.0     0.01
# 1             59.9            271.0           64.0     0.01
# 2             59.9            268.0           66.0     0.01
#
#    percentage_expenditure  Hepatitis_B  Measles   BMI  under_five_deaths  \
# 0               71.279624         65.0   1154.0  19.1               83.0
# 1               73.523582         62.0    492.0  18.6               86.0
# 2               73.219243         64.0    430.0  18.1               89.0
#
#    Polio  Total_expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
#
#    thinness__1_19_years  thinness_5_9_years  Income_composition_of_resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
#
#    Schooling  Status_Developing
# 0       10.1                  1
# 1       10.0                  1
# 2        9.9                  1

# %%
df_base.shape, df_num.shape
# Out:
# ((911, 20), (2938, 20))

# %%
df_num.shape
# Out:
# (2938, 20)

# %%
print('loss of :', 100 - (911/2938)*100, '% of observation if drop all the null value of the dataset')
# Out:
# loss of : 68.9925119128659 % of observation if drop all the null value

# %%
# higher the R_square, better the model
# Add constant to X and set X & y values to fit linear model
X = sm.add_constant(df_base.iloc[:, 1: ])
y = df_base['Life_expectancy']
lm = sm.OLS(y, X).fit()

# Print summary of lm
print('\nSummary: ', lm.summary())

# Print R squared score of lm
print('\nAdjusted R-squared score: ', lm.rsquared_adj)

# Print the params of lm
print('\nCoefficcients:\n', lm.params)
# Out:
# Summary:                              OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_expectancy   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.899
# Method:                 Least Squares   F-statistic:                     428.3
# Date:                Wed, 03 Nov 2021   Prob (F-statistic):               0.00
# Time:                        18:32:32   Log-Likelihood:                -2285.4
# No. Observations:                 911   AIC:                             4611.
# Df Residuals:                     891   BIC:                             4707.
# Df Model:                          19
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              46.3606      0.971     47.727      0.000      44.454      48.267
# Adult_Mortality                    -0.0119      0.001    -11.790      0.000      -0.014      -0.010
# infant_deaths                       0.0466      0.009      4.977      0.000       0.028       0.065
# Alcohol                            -0.2262      0.038     -5.902      0.000      -0.301      -0.151
# percentage_expenditure              0.0007      0.000      3.660      0.000       0.000       0.001
# Hepatitis_B                        -0.0070      0.005     -1.437      0.151      -0.017       0.003
# Measles                          8.011e-06   9.21e-06      0.869      0.385   -1.01e-05    2.61e-05
# BMI                                 0.0060      0.008      0.767      0.443      -0.009       0.021
# under_five_deaths                  -0.0357      0.007     -5.261      0.000      -0.049      -0.022
# Polio                               0.0020      0.006      0.353      0.724      -0.009       0.013
# Total_expenditure                   0.1403      0.047      2.956      0.003       0.047       0.233
# Diphtheria                          0.0167      0.007      2.556      0.011       0.004       0.029
# HIV/AIDS                           -0.3302      0.019    -17.001      0.000      -0.368      -0.292
# GDP                             -7.449e-05   3.18e-05     -2.340      0.020      -0.000    -1.2e-05
# Population                      -3.015e-10   1.49e-09     -0.202      0.840   -3.23e-09    2.62e-09
# thinness__1_19_years                0.0941      0.046      2.042      0.041       0.004       0.184
# thinness_5_9_years                 -0.0862      0.046     -1.889      0.059      -0.176       0.003
# Income_composition_of_resources    48.7312      2.109     23.106      0.000      44.592      52.870
# Schooling                          -0.5062      0.097     -5.231      0.000      -0.696      -0.316
# Status_Developing                  -1.6337      0.412     -3.961      0.000      -2.443      -0.824
# ==============================================================================
# Omnibus:                       45.171   Durbin-Watson:                   0.785
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              116.439
# Skew:                           0.222   Prob(JB):                     5.20e-26
# Kurtosis:                       4.694   Cond. No.                     2.07e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.07e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Adjusted R-squared score:  0.8992031680869179
#
# Coefficcients:
#  const                              4.636057e+01
# Adult_Mortality                   -1.189334e-02
# infant_deaths                      4.661857e-02
# Alcohol                           -2.261891e-01
# percentage_expenditure             7.099966e-04
# Hepatitis_B                       -6.988093e-03
# Measles                            8.011312e-06
# BMI                                6.015232e-03
# under_five_deaths                 -3.567852e-02
# Polio                              1.991430e-03
# Total_expenditure                  1.403110e-01
# Diphtheria                         1.665471e-02
# HIV/AIDS                          -3.301815e-01
# GDP                               -7.448993e-05
# Population                        -3.015448e-10
# thinness__1_19_years               9.405682e-02
# thinness_5_9_years                -8.616976e-02
# Income_composition_of_resources    4.873117e+01
# Schooling                         -5.062304e-01
# Status_Developing                 -1.633694e+00
# dtype: float64
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
lm

# %%
#data_NAN_mean.iloc[:,:].head()

# %%
# Mean Imputation
X = sm.add_constant(data_NAN_mean.iloc[:,1:])
y = data_NAN_mean['Life_expectancy']
lm_mean = sm.OLS(y, X).fit()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
#KNN imputation (missing value)
X = sm.add_constant(df_knn_imputed.iloc[:, 1:])
y = df_knn_imputed['Life_expectancy']
lm_KNN = sm.OLS(y, X).fit()

# %%
#MIce imputation 
X = sm.add_constant(df_mice_imputed.iloc[:, 1:])
y = df_mice_imputed['Life_expectancy']
lm_MICE = sm.OLS(y, X).fit()

# %%
# Store the Adj. R-squared scores of the linear models
r_squared = pd.DataFrame({'Complete Case': lm.rsquared_adj, 
                          'Mean Imputation': lm_mean.rsquared_adj, 
                          'KNN Imputation': lm_KNN.rsquared_adj, 
                          'MICE Imputation': lm_MICE.rsquared_adj}, 
                         index=['Adj. R-squared'])

print(r_squared)
# Out:
#                 Complete Case  Mean Imputation  KNN Imputation  \
# Adj. R-squared       0.899203         0.836848        0.853227
#
#                 MICE Imputation
# Adj. R-squared         0.901034

# %%
# Store the coefficients of the linear models
coeff = pd.DataFrame({'Complete Case': lm.params, 
                          'Mean Imputation': lm_mean.params, 
                          'KNN Imputation': lm_KNN.params, 
                          'MICE Imputation': lm_MICE.params})

print(coeff)
# Out:
#                                  Complete Case  Mean Imputation  \
# const                             4.636057e+01     4.965945e+01
# Adult_Mortality                  -1.189334e-02    -1.798005e-02
# infant_deaths                     4.661857e-02     6.437503e-02
# Alcohol                          -2.261891e-01    -3.068395e-02
# percentage_expenditure            7.099966e-04     1.920706e-04
# Hepatitis_B                      -6.988093e-03    -1.789519e-02
# Measles                           8.011312e-06    -2.858958e-05
# BMI                               6.015232e-03     2.492151e-02
# under_five_deaths                -3.567852e-02    -4.828564e-02
# Polio                             1.991430e-03     2.121920e-02
# Total_expenditure                 1.403110e-01     1.511922e-01
# Diphtheria                        1.665471e-02     3.924685e-02
# HIV/AIDS                         -3.301815e-01    -4.029636e-01
# GDP                              -7.448993e-05    -1.310958e-05
# Population                       -3.015448e-10     1.112080e-09
# thinness__1_19_years              9.405682e-02    -4.178821e-02
# thinness_5_9_years               -8.616976e-02     6.384010e-03
# Income_composition_of_resources   4.873117e+01     2.497641e+01
# Schooling                        -5.062304e-01     2.323368e-01
# Status_Developing                -1.633694e+00    -1.293486e+00
#
#                                  KNN Imputation  MICE Imputation
# const                              4.740114e+01     4.258084e+01
# Adult_Mortality                   -1.563369e-02    -1.040008e-02
# infant_deaths                      9.878792e-02     6.487492e-02
# Alcohol                           -4.268860e-02    -1.645396e-01
# percentage_expenditure             2.670677e-04     5.555493e-04
# Hepatitis_B                       -9.911815e-03    -1.171936e-03
# Measles                           -2.357211e-05    -1.542538e-08
# BMI                                8.920551e-03    -3.763375e-03
# under_five_deaths                 -7.453599e-02    -4.862009e-02
# Polio                              1.553826e-02     9.818022e-03
# Total_expenditure                  1.302651e-01     2.343257e-01
# Diphtheria                         2.564895e-02     1.336768e-02
# HIV/AIDS                          -3.961620e-01    -3.825468e-01
# GDP                               -1.676262e-05    -7.713968e-05
# Population                         5.778067e-10    -1.358712e-09
# thinness__1_19_years               9.201133e-03     5.244330e-02
# thinness_5_9_years                 8.757614e-03    -4.350432e-02
# Income_composition_of_resources    3.248998e+01     4.797309e+01
# Schooling                          6.121761e-02    -3.376069e-01
# Status_Developing                 -7.972656e-01    -4.394922e-01

# %% [markdown]
# ## Select the best imputation based on the R-squared score.

# %%
r_squares = {'Mean Imputation': lm_mean.rsquared_adj, 
             'KNN Imputation': lm_KNN.rsquared_adj, 
             'MICE Imputation': lm_MICE.rsquared_adj}

# Select best R-squared / use max(), the higher R-square, better the model
best_imputation = max(r_squares, key=r_squares.get)

print("The best imputation technique is: ", best_imputation)
# Out:
# The best imputation technique is:  MICE Imputation

# %% [markdown]
# ### Comparing density plot

# %%
# Plot graphs of imputed DataFrames and the complete case
df_base['Population'].plot(kind='kde', c='red', linewidth=3)
data_NAN_mean['Population'].plot(kind='kde') # diabetes_mean / diabetes_mean_imputed
df_knn_imputed['Population'].plot(kind='kde')
df_mice_imputed['Population'].plot(kind='kde')

# Create labels for the four DataFrames
labels = ['Baseline (Complete Case)', 'Mean Imputation', 'KNN Imputation', 'MICE Imputation']
plt.legend(labels)

# Set the x-label as Skin Fold
plt.xlabel('Population')

plt.show()

# %% [markdown]
# Questions:
#
# which itinerary technique to use:
# do I need to tread outlier before imputing missing data?
# or imputing missing data and next outlier?

# %% [markdown]
# #### Save dataset

# %%
import os
import pickle
from library.sb_utils import save_file

# %%
data_Zero_NAN # Raw data -- replace 0 with NaN

# %%
data_outlier_vinso # Raw data -- replace 0 with NaN --, outlier treated with winzorisation

# %%
# Raw data -- replace 0 with NaN --- label encoder of cat var (Status_Developing) (1 - develp , 0- )
data_cat_encode.head(3)
# Out:
#        Country       Year  Life_expectancy  Adult_Mortality  infant_deaths  \
# 0  Afghanistan 2015-01-01             65.0            263.0           62.0
# 1  Afghanistan 2014-01-01             59.9            271.0           64.0
# 2  Afghanistan 2013-01-01             59.9            268.0           66.0
#
#    Alcohol  percentage_expenditure  Hepatitis_B  Measles   BMI  ...  \
# 0     0.01               71.279624         65.0   1154.0  19.1  ...
# 1     0.01               73.523582         62.0    492.0  18.6  ...
# 2     0.01               73.219243         64.0    430.0  18.1  ...
#
#    Total_expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0               8.16        65.0       0.1  584.259210  33736494.0
# 1               8.18        62.0       0.1  612.696514    327582.0
# 2               8.13        64.0       0.1  631.744976  31731688.0
#
#    thinness__1_19_years  thinness_5_9_years  Income_composition_of_resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
#
#    Schooling  Status_Developing
# 0       10.1                  1
# 1       10.0                  1
# 2        9.9                  1
#
# [3 rows x 22 columns]

# %%
# the best imputation with mice------- mice - dataset 
#( replace 0 with NaN --- label encoder of cat var (Status_Developing) (1 - develp , 0- ) , mice imputation)
df_mice_imputed.head(3)
# Out:
#    Life_expectancy  Adult_Mortality  infant_deaths  Alcohol  \
# 0             65.0            263.0           62.0     0.01
# 1             59.9            271.0           64.0     0.01
# 2             59.9            268.0           66.0     0.01
#
#    percentage_expenditure  Hepatitis_B  Measles   BMI  under_five_deaths  \
# 0               71.279624         65.0   1154.0  19.1               83.0
# 1               73.523582         62.0    492.0  18.6               86.0
# 2               73.219243         64.0    430.0  18.1               89.0
#
#    Polio  Total_expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
#
#    thinness__1_19_years  thinness_5_9_years  Income_composition_of_resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
#
#    Schooling  Status_Developing
# 0       10.1                1.0
# 1       10.0                1.0
# 2        9.9                1.0

# %%
msno.matrix(df_mice_imputed)
display("/usr/local/share/datasets/matrix.png")
# Out:
# '/usr/local/share/datasets/matrix.png'

# %%
# add the first column to mice dataset 
df_mice_imputed.insert(0,'Country', data_cat_encode['Country'], allow_duplicates=True)

# %%
df_mice_imputed.head(3)
# Out:
#        Country  Life_expectancy  Adult_Mortality  infant_deaths  Alcohol  \
# 0  Afghanistan             65.0            263.0           62.0     0.01
# 1  Afghanistan             59.9            271.0           64.0     0.01
# 2  Afghanistan             59.9            268.0           66.0     0.01
#
#    percentage_expenditure  Hepatitis_B  Measles   BMI  under_five_deaths  ...  \
# 0               71.279624         65.0   1154.0  19.1               83.0  ...
# 1               73.523582         62.0    492.0  18.6               86.0  ...
# 2               73.219243         64.0    430.0  18.1               89.0  ...
#
#    Total_expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0               8.16        65.0       0.1  584.259210  33736494.0
# 1               8.18        62.0       0.1  612.696514    327582.0
# 2               8.13        64.0       0.1  631.744976  31731688.0
#
#    thinness__1_19_years  thinness_5_9_years  Income_composition_of_resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
#
#    Schooling  Status_Developing
# 0       10.1                1.0
# 1       10.0                1.0
# 2        9.9                1.0
#
# [3 rows x 21 columns]

# %%
# Save the data 
datapath = '../data'
save_file(df_mice_imputed, 'life_exp_imput_mice.csv', datapath)
# Out:
# Directory ../data was created.
# Writing file.  "../data\life_exp_imput_mice.csv"

# %%
#data_Zero_NAN # Raw data -- replace 0 with NaN 
save_file(data_Zero_NAN, 'life_exp_Zero_Nan.csv', datapath)
# Out:
# Writing file.  "../data\life_exp_Zero_Nan.csv"
